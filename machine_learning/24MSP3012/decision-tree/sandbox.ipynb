# %% [markdown]
# # Decision Tree Classifier

# %%
import pandas as pd  # Importing pandas for data manipulation
from sklearn.datasets import load_breast_cancer  # To load the Breast Cancer dataset
from sklearn.model_selection import train_test_split  # To split the dataset into training and testing sets
from sklearn.tree import DecisionTreeClassifier  # Importing the Decision Tree Classifier
from sklearn import metrics  # To evaluate the accuracy of the model
from sklearn.tree import plot_tree  # To visualize the decision tree
import matplotlib.pyplot as plt  # For plotting

# %%
# Load the Breast Cancer dataset from sklearn
data = pd.read_csv("./breast-cancer.csv")

# %%
# select features
features = ["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean",
            "concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se",
            "texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se",
            "concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst",
            "perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst",
            "concave points_worst","symmetry_worst","fractal_dimension_worst"]

# %%
# Convert the dataset into a DataFrame
X = pd.DataFrame(data, columns=features).to_numpy()  # Feature matrix
y = pd.DataFrame(data, columns=["diagnosis"]).to_numpy()  # Target labels

# %%
print(X[:2])
# Out:
# [[1.799e+01 1.038e+01 1.228e+02 1.001e+03 1.184e-01 2.776e-01 3.001e-01
#   1.471e-01 2.419e-01 7.871e-02 1.095e+00 9.053e-01 8.589e+00 1.534e+02
#   6.399e-03 4.904e-02 5.373e-02 1.587e-02 3.003e-02 6.193e-03 2.538e+01
#   1.733e+01 1.846e+02 2.019e+03 1.622e-01 6.656e-01 7.119e-01 2.654e-01
#   4.601e-01 1.189e-01]
#  [2.057e+01 1.777e+01 1.329e+02 1.326e+03 8.474e-02 7.864e-02 8.690e-02
#   7.017e-02 1.812e-01 5.667e-02 5.435e-01 7.339e-01 3.398e+00 7.408e+01
#   5.225e-03 1.308e-02 1.860e-02 1.340e-02 1.389e-02 3.532e-03 2.499e+01
#   2.341e+01 1.588e+02 1.956e+03 1.238e-01 1.866e-01 2.416e-01 1.860e-01
#   2.750e-01 8.902e-02]]

# %%
print(y[:2])
# Out:
# [['M']
#  ['M']]

# %%
# split into training and testing sets
X_train, X_test, y_train, y_test, = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=123)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=123)

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test)

# %%
# Evaluate the accuracy of the model
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Accuracy of the Decision Tree model: {accuracy * 100:.2f}%")
# Out:
# Accuracy of the Decision Tree model: 95.61%

# %%
# Visualize the decision tree
plt.figure(figsize=(20,10))  # Set the figure size
plot_tree(clf, filled=True, feature_names=X[:], class_names=data.diagnosis)
plt.show()

# %%
# Example of classifying a new sample
new_sample = [[14.0, 20.0, 90.0, 600.0, 0.1, 0.15, 0.2, 0.1, 0.2, 0.05,
            0.4, 1.0, 3.0, 50.0, 0.807, 0.04, 0.05, 0.02, 0.02, 0.005,
            16.0, 30.0, 100.0, 800.0, 0.15, 0.85, 0.3, 0.45, 0.3, 0.07]]

# %%
# Predict the class for the new sample
new_prediction = clf.predict(new_sample)
print(f"The predicted class for the new sample is: {[new_prediction[0]]}")
# Out:
# The predicted class for the new sample is: ['M']
